# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("train.csv")
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
mi = df.isnull().sum()/df.shape[0]*100
mi
# Out:
# Item_Identifier               0.000000
# Item_Weight                  17.165317
# Item_Fat_Content              0.000000
# Item_Visibility               0.000000
# Item_Type                     0.000000
# Item_MRP                      0.000000
# Outlet_Identifier             0.000000
# Outlet_Establishment_Year     0.000000
# Outlet_Size                  28.276428
# Outlet_Location_Type          0.000000
# Outlet_Type                   0.000000
# Item_Outlet_Sales             0.000000
# dtype: float64

# %%
drop = mi[mi>20].keys()
drop
# Out:
# Index(['Outlet_Size'], dtype='object')

# %%
df1 = df.drop(drop, axis=1)
df1.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Location_Type        Outlet_Type  \
# 0                       1999               Tier 1  Supermarket Type1
# 1                       2009               Tier 3  Supermarket Type2
# ...

# %%
df1.shape
# Out:
# (8523, 11)

# %%
df1.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Location_Type       8523 non-null   object
#  9   Outlet_Type                8523 non-null   object
#  10  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 732.6+ KB

# %%
df1["Item_Weight"] = df1["Item_Weight"].fillna(df1["Item_Weight"].mean())

# %%
df1.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
cat_cols = df1.select_dtypes("O").keys()
cat_cols
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#        'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
for var in cat_cols:
    print(df1[var].value_counts())
# Out:
# FDW13    10
# FDG33    10
# NCY18     9
# FDD38     9
# DRE49     9
# FDV60     9
# NCQ06     9
# FDF52     9
# FDX04     9
# NCJ30     9
# FDV38     9
# NCF42     9
# FDT07     9
# FDW26     9
# NCL31     9
# FDU12     9
# FDG09     9
# FDQ40     9
# FDX20     9
# NCI54     9
# FDX31     9
# FDP25     9
# FDW49     9
# FDF56     9
# FDO19     9
# DRN47     9
# NCB18     9
# FDE11     8
# NCX05     8
# FDQ39     8
# FDT55     8
# FDO32     8
# FDT40     8
# FDZ20     8
# FDH27     8
# FDY49     8
# FDS33     8
# FDR04     8
# FDR43     8
# FDR59     8
# FDJ55     8
# FDT24     8
# FDY55     8
# FDV09     8
# FDU23     8
# FDY47     8
# DRD25     8
# FDK58     8
# FDL58     8
# FDX58     8
# FDR44     8
# FDP28     8
# FDA39     8
# FDH28     8
# DRF27     8
# FDX21     8
# FDY56     8
# FDF05     8
# FDL20     8
# FDY03     8
# NCK05     8
# FDS55     8
# DRA59     8
# FDG24     8
# NCE54     8
# FDZ21     8
# FDA04     8
# FDW24     8
# FDT49     8
# DRF23     8
# FDD05     8
# ...

# %%
df1["Item_Identifier"].value_counts()
# Out:
# FDW13    10
# FDG33    10
# NCY18     9
# FDD38     9
# DRE49     9
# FDV60     9
# NCQ06     9
# FDF52     9
# FDX04     9
# NCJ30     9
# FDV38     9
# NCF42     9
# FDT07     9
# FDW26     9
# NCL31     9
# FDU12     9
# FDG09     9
# FDQ40     9
# FDX20     9
# NCI54     9
# FDX31     9
# FDP25     9
# FDW49     9
# FDF56     9
# FDO19     9
# DRN47     9
# NCB18     9
# FDE11     8
# NCX05     8
# FDQ39     8
# FDT55     8
# FDO32     8
# FDT40     8
# FDZ20     8
# FDH27     8
# FDY49     8
# FDS33     8
# FDR04     8
# FDR43     8
# FDR59     8
# FDJ55     8
# FDT24     8
# FDY55     8
# FDV09     8
# FDU23     8
# FDY47     8
# DRD25     8
# FDK58     8
# FDL58     8
# FDX58     8
# FDR44     8
# FDP28     8
# FDA39     8
# FDH28     8
# DRF27     8
# FDX21     8
# FDY56     8
# FDF05     8
# FDL20     8
# FDY03     8
# NCK05     8
# FDS55     8
# DRA59     8
# FDG24     8
# NCE54     8
# FDZ21     8
# FDA04     8
# FDW24     8
# FDT49     8
# DRF23     8
# FDD05     8
# ...

# %%
df2 = df1.copy()
value = df2["Item_Identifier"].value_counts()
dummy = value[value>8].keys()
dummy
# Out:
# Index(['FDW13', 'FDG33', 'NCY18', 'FDD38', 'DRE49', 'FDV60', 'NCQ06', 'FDF52',
#        'FDX04', 'NCJ30', 'FDV38', 'NCF42', 'FDT07', 'FDW26', 'NCL31', 'FDU12',
#        'FDG09', 'FDQ40', 'FDX20', 'NCI54', 'FDX31', 'FDP25', 'FDW49', 'FDF56',
#        'FDO19', 'DRN47', 'NCB18'],
#       dtype='object')

# %%
for var in dummy:
    df2["Item_Identifier_"+var] = np.where(df2["Item_Identifier"]==var,1,0)

# %%
df2.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Location_Type        Outlet_Type  \
# 0                       1999               Tier 1  Supermarket Type1
# 1                       2009               Tier 3  Supermarket Type2
# ...

# %%
df2.shape
# Out:
# (8523, 38)

# %%
df2.drop("Item_Identifier", axis=1, inplace=True)

# %%
df3 = pd.get_dummies(df2)
df3.shape
# Out:
# (8523, 70)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 70 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Item_Weight                      8523 non-null   float64
#  1   Item_Visibility                  8523 non-null   float64
#  2   Item_MRP                         8523 non-null   float64
#  3   Outlet_Establishment_Year        8523 non-null   int64
#  4   Item_Outlet_Sales                8523 non-null   float64
#  5   Item_Identifier_FDW13            8523 non-null   int32
#  6   Item_Identifier_FDG33            8523 non-null   int32
#  7   Item_Identifier_NCY18            8523 non-null   int32
#  8   Item_Identifier_FDD38            8523 non-null   int32
#  9   Item_Identifier_DRE49            8523 non-null   int32
#  10  Item_Identifier_FDV60            8523 non-null   int32
#  11  Item_Identifier_NCQ06            8523 non-null   int32
# ...

# %% [markdown]
# ## data visulization

# %%
df3_cols = df3.columns
df3_cols
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Establishment_Year', 'Item_Outlet_Sales',
#        'Item_Identifier_FDW13', 'Item_Identifier_FDG33',
#        'Item_Identifier_NCY18', 'Item_Identifier_FDD38',
#        'Item_Identifier_DRE49', 'Item_Identifier_FDV60',
#        'Item_Identifier_NCQ06', 'Item_Identifier_FDF52',
#        'Item_Identifier_FDX04', 'Item_Identifier_NCJ30',
#        'Item_Identifier_FDV38', 'Item_Identifier_NCF42',
#        'Item_Identifier_FDT07', 'Item_Identifier_FDW26',
#        'Item_Identifier_NCL31', 'Item_Identifier_FDU12',
#        'Item_Identifier_FDG09', 'Item_Identifier_FDQ40',
#        'Item_Identifier_FDX20', 'Item_Identifier_NCI54',
#        'Item_Identifier_FDX31', 'Item_Identifier_FDP25',
#        'Item_Identifier_FDW49', 'Item_Identifier_FDF56',
#        'Item_Identifier_FDO19', 'Item_Identifier_DRN47',
#        'Item_Identifier_NCB18', 'Item_Fat_Content_LF',
# ...

# %%
df_cols = df.columns
df_cols
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
cat_cols
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#        'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %%
num_cols = df.select_dtypes(["int64", "float64"]).keys()
num_cols
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Establishment_Year', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
from matplotlib import style
style.use("ggplot")
plt.figure(figsize=(16,9))
sns.distplot(df3["Item_Visibility"])
plt.title("Item_Visibility")
plt.show()

# %%
plt.figure(figsize=(16,9))
sns.distplot(df3["Item_Weight"])
plt.title("Item_Weight")
plt.show()

# %%
plt.figure(figsize=(16,9))
sns.distplot(df3["Item_MRP"])
plt.title("Item_MRP")
plt.show()

# %%
plt.figure(figsize=(16,9))
sns.distplot(df3["Outlet_Establishment_Year"])
plt.title("Outlet_Establishment_Year")
plt.show()

# %%
plt.figure(figsize=(16,9))
sns.distplot(df3["Item_Outlet_Sales"])
plt.title("Item_Outlet_Sales")
plt.show()

# %%
num_cols
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Establishment_Year', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
plt.figure(figsize=(16,9))
plt.hist(df3["Item_Weight"], rwidth=0.8)
plt.title("hist of Item_Weight")
plt.xlabel("Item_Weight")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(16,9))
plt.hist(df3["Item_Visibility"], rwidth=0.8)
plt.title("hist of Item_Visibility")
plt.xlabel("Item_Visibility")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(16,9))
plt.hist(df3["Item_MRP"], rwidth=0.8)
plt.title("hist of Item_MRP")
plt.xlabel("Item_MRP")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(16,9))
plt.hist(df3["Outlet_Establishment_Year"], rwidth=0.8)
plt.title("hist of ItemOutlet_Establishment_Year_Weight")
plt.xlabel("Outlet_Establishment_Year")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(16,9))
plt.hist(df3["Item_Outlet_Sales"], rwidth=0.8)
plt.title("hist of Item_Outlet_Sales")
plt.xlabel("Item_Outlet_Sales")
plt.ylabel("Count")
plt.show()

# %%
num_cols
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Establishment_Year', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
corr1 = df3["Item_Outlet_Sales"].corr(df3["Item_Weight"])
corr1
# Out:
# 0.011550000817702384

# %%
df.corr()
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.014048  0.027141
# Item_Visibility              -0.014048         1.000000 -0.001315
# Item_MRP                      0.027141        -0.001315  1.000000
# Outlet_Establishment_Year    -0.011588        -0.074834  0.005020
# Item_Outlet_Sales             0.014123        -0.128625  0.567574
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                -0.011588           0.014123
# Item_Visibility                            -0.074834          -0.128625
# Item_MRP                                    0.005020           0.567574
# Outlet_Establishment_Year                   1.000000          -0.049135
# Item_Outlet_Sales                          -0.049135           1.000000

# %%
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
df3_cols
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Establishment_Year', 'Item_Outlet_Sales',
#        'Item_Identifier_FDW13', 'Item_Identifier_FDG33',
#        'Item_Identifier_NCY18', 'Item_Identifier_FDD38',
#        'Item_Identifier_DRE49', 'Item_Identifier_FDV60',
#        'Item_Identifier_NCQ06', 'Item_Identifier_FDF52',
#        'Item_Identifier_FDX04', 'Item_Identifier_NCJ30',
#        'Item_Identifier_FDV38', 'Item_Identifier_NCF42',
#        'Item_Identifier_FDT07', 'Item_Identifier_FDW26',
#        'Item_Identifier_NCL31', 'Item_Identifier_FDU12',
#        'Item_Identifier_FDG09', 'Item_Identifier_FDQ40',
#        'Item_Identifier_FDX20', 'Item_Identifier_NCI54',
#        'Item_Identifier_FDX31', 'Item_Identifier_FDP25',
#        'Item_Identifier_FDW49', 'Item_Identifier_FDF56',
#        'Item_Identifier_FDO19', 'Item_Identifier_DRN47',
#        'Item_Identifier_NCB18', 'Item_Fat_Content_LF',
# ...

# %%
li = ['Item_Weight', 'Item_Visibility', 'Item_MRP','Outlet_Establishment_Year', 'Item_Outlet_Sales', 'Item_Identifier_FDW13', 'Item_Fat_Content_Low Fat', 'Item_Type_Baking Goods',
       'Outlet_Identifier_OUT010','Outlet_Location_Type_Tier 1', 'Outlet_Type_Grocery Store']
li
# Out:
# ['Item_Weight',
#  'Item_Visibility',
#  'Item_MRP',
#  'Outlet_Establishment_Year',
#  'Item_Outlet_Sales',
#  'Item_Identifier_FDW13',
#  'Item_Fat_Content_Low Fat',
#  'Item_Type_Baking Goods',
#  'Outlet_Identifier_OUT010',
#  'Outlet_Location_Type_Tier 1',
#  'Outlet_Type_Grocery Store']

# %%
for var in li:
    sns.boxplot(df3[var])
    plt.title(f"boxplot in {var}")
    plt.show()

# %%
for var in li:
    sns.displot(df3[var])
    plt.title(f"boxplot in {var}")
    plt.show()

# %%
X = df3.drop("Item_Outlet_Sales", axis=1)
y = df3["Item_Outlet_Sales"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(X_train, y_train)
X_train = sc.transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
lr.score(X_test, y_test)
# Out:
# 0.5636687086418622

# %%
rd = Ridge()
rd.fit(X_train, y_train)
y_pred1 = rd.predict(X_test)
rd.score(X_test, y_test)
# Out:
# 0.5630343521978933

# %%
lc = Lasso()
lc.fit(X_train, y_train)
y_pred2 = lc.predict(X_test)
lc.score(X_test, y_test)
# Out:
# 0.5634996891157261

# %%
from sklearn.svm import SVR
svr = SVR()
svr.fit(X_train, y_train)
y_pred3 = svr.predict(X_test)
svr.score(X_test, y_test)
# Out:
# 0.01650217565991663

# %%
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor()
dtr.fit(X_train, y_train)
y_pred4 = dtr.predict(X_test)
dtr.score(X_test, y_test)
# Out:
# 0.17100990471938682

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor()
rfr.fit(X_train, y_train)
y_pred5 = rfr.predict(X_test)
rfr.score(X_test, y_test)
# Out:
# 0.5450764596582875

# %%
from sklearn.neighbors import KNeighborsRegressor
knr = KNeighborsRegressor()
knr.fit(X_train, y_train)
y_pred6 = knr.predict(X_test)
knr.score(X_test, y_test)
# Out:
# 0.4332875604068055

# %%
from sklearn.neural_network import MLPRegressor
mlp = MLPRegressor()
mlp.fit(X_train, y_train)
y_pred7 = mlp.predict(X_test)
mlp.score(X_test, y_test)
# Out:
# 0.5933761041207961

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr = GradientBoostingRegressor()
gbr.fit(X_train, y_train)
y_pred8 = gbr.predict(X_test)
gbr.score(X_test, y_test)
# Out:
# 0.6024454333137823

# %%
from sklearn.ensemble import AdaBoostRegressor
ada = AdaBoostRegressor()
ada.fit(X_train, y_train)
y_pred9 = ada.predict(X_test)
ada.score(X_test, y_test)
# Out:
# 0.5086355861588832

# %%
from sklearn.model_selection import cross_val_score
cv = cross_val_score(gbr, X_train, y_train, cv=10)
cv, cv.mean()
# Out:
# (array([0.60220923, 0.62075212, 0.63217321, 0.57177086, 0.58019239,
#         0.58194251, 0.57036645, 0.58200112, 0.57340111, 0.60018601]),
#  0.5914994988401837)

# %%
def Item_outlet_salesprice_prediction(model, Item_Weight, Item_Visibility, Item_MRP, Outlet_Establishment_Year, Item_Identifier, 
                            Item_Fat_Content, Item_Type, Outlet_Identifier, Outlet_Location_Type, Outlet_Type):
    x=np.zeros(len(X.columns))
    x[0]= Item_Weight
    x[1]=Item_Visibility
    x[2]=Item_MRP
    x[3]=Outlet_Establishment_Year
    
    if "Item_Identifier_"+Item_Identifier in X.columns:
        Item_Identifier_index = np.where(X.columns=="Item_Identifier_"+Item_Identifier)[0][0]
        x[Item_Identifier_index]=1
        
    if "Item_Fat_Content_"+Item_Fat_Content in X.columns:
        Item_Fat_Content_index = np.where(X.columns=="Item_Fat_Content_"+Item_Fat_Content)[0][0]
        x[Item_Fat_Content_index]=1

    if "Item_Type_"+Item_Type in X.columns:
        Item_Type_index = np.where(X.columns=="Item_Type_"+Item_Type)[0][0]
        x[Item_Type_index]=1
        
    if "Outlet_Identifier_"+Outlet_Identifier in X.columns:
        Outlet_Identifier_index = np.where(X.columns=="Outlet_Identifier_"+Outlet_Identifier)[0][0]
        x[Outlet_Identifier_index]=1

    if "Outlet_Location_Type_"+Outlet_Location_Type in X.columns:
        Outlet_Location_Type_index = np.where(X.columns=="Outlet_Location_Type_"+Outlet_Location_Type)[0][0]
        x[Outlet_Location_Type_index]=1
        
    if "Outlet_Type_"+Outlet_Type in X.columns:
        Outlet_Type_index = np.where(X.columns=="Outlet_Type_"+Outlet_Type)[0][0]
        x[Outlet_Type_index]=1
        
    x = sc.transform([x])[0]
    
    return model.predict([x])[0]

# %%
import joblib

# %%
joblib.dump(gbr, "Item_outlet_sales_prediction.pkl")
# Out:
# ['Item_outlet_sales_prediction.pkl']

# %%
model = joblib.load("Item_outlet_sales_prediction.pkl")

# %%
# FDA15	9.30	Low Fat	0.016047	Dairy	249.8092	OUT049	1999	Medium	Tier 1	Supermarket Type1

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# model, Item_Weight, Item_Visibility, Item_MRP, Outlet_Establishment_Year, Item_Identifier, 
#                             Item_Fat_Content, Item_Type, Outlet_Identifier, Outlet_Location_Type, Outlet_Type

# %%
Item_outlet_salesprice_prediction(model, Item_Weight=9.30, Item_Visibility=0.016047, Item_MRP=249.8092,Outlet_Establishment_Year= 1999,
                                  Item_Identifier="FDA15", Item_Fat_Content="Low Fat", Item_Type="Dairy", Outlet_Identifier="OUT049",
                                 Outlet_Location_Type="Tier 1", Outlet_Type="Supermarket Type1")
# Out:
# 4194.111047182961
